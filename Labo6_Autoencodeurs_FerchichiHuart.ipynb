# %% [markdown]
# <img src="https://heig-vd.ch/docs/default-source/doc-global-newsletter/2020-slim.svg" alt="Logo HEIG-VD" style="width: 80px;" align="right"/>
#
# # Cours APN - Labo 6 : Autoencodeurs et détection de fraudes
#
# ## Résumé
# Le but de ce laboratoire est d'entraîner des autoencodeurs sur des données de transactions bancaires, en mode non supervisé.  La fonction de coût sera la capacité de l'autoencodeur à reproduire en sortie les données d'entrée.  Trois réseaux de neurones autoencodeurs seront testés.
#
# Ensuite, on considérera que les données mal reconstruites sont atypiques, et on testera l'hypothèse qu'il s'agit de transactions frauduleuses.  On utilisera donc cette information pour évaluer la capacité de l'autoencodeur à détecter les fraudes.

# %%
import numpy as np
import pandas as pd
import keras # pour l'installation, "pip install tensorflow" suffira
import tensorflow as tf
# Out:
# 2023-12-15 18:03:32.814629: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split 
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay, average_precision_score
from sklearn.metrics import roc_curve, RocCurveDisplay, roc_auc_score
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.environ['TF_CPP_MAX_VLOG_LEVEL'] = '-1'

# %% [markdown]
# ## 1. Données : source
#
# Vous utiliserez un jeu de données fourni par le [Groupe ML de l'Université Libre de Bruxelles](http://mlg.ulb.ac.be/), disponible sur Kaggle : https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud.  Pour simplifier, une version vous est fournie sur Switchdrive dans un fichier [creditcard.zip](https://drive.switch.ch/index.php/s/lBqMRsADWrU2S4R).  Voici la description des données par les auteurs :
#
# > The dataset contains transactions made by credit cards over two days in September 2013 by European cardholders.  It contains only numerical input variables which are the result of a PCA transformation (due to confidentiality issues).  Features V1, ..., V28 are the principal components.  Two features were not transformed: 'Time' (seconds since the 1st transaction) and 'Amount'.
#
# > The feature 'Class' takes value 1 in case of a fraudulent transaction and 0 otherwise.  There are 492 frauds out of 284,807 transactions (0.17%).  As the dataset is highly unbalanced, we recommend measuring the accuracy using the Area Under the Precision-Recall Curve (AUPRC), not with confusion matrices.

# %% [markdown]
# ## 1. Charger et préparer les données
# a. Chargez les données de `creditcard.csv` directement dans une *dataframe* Pandas appelée `data`.

# %%
data = pd.read_csv("creditcard.csv")
data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# b. Affichez quelques informations sur ces données et leurs caractéristiques.

# %%
print(f"Longueur: {len(data)}")
data.describe().loc[["mean", "std", "min", "50%", "max"]]
# Out:
# Longueur: 284807
#                Time            V1            V2            V3            V4  \
# mean   94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std    47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min        0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 50%    84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# max   172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                 V5            V6            V7            V8            V9  \
# mean  9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std   1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min  -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 50%  -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# max   3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#       ...           V21           V22           V23           V24  \
# mean  ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std   ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min   ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 50%   ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# max   ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                V25           V26           V27           V28        Amount  \
# mean  5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16     88.349619
# std   5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01    250.120109
# min  -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01      0.000000
# 50%   1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02     22.000000
# max   7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01  25691.160000
#
#          Class
# mean  0.001727
# std   0.041527
# min   0.000000
# 50%   0.000000
# max   1.000000
#
# [5 rows x 31 columns]

# %% [markdown]
# c. Construisez une nouvelle *dataframe* appelée `data_labels` contenant seulement l'attribut qui indique si une transaction est frauduleuse ou non (attribut `Class`).  Supprimez les attributs `Time` et `Class` de la *dataframe* initiale `data`.

# %%
data_labels = pd.DataFrame(data["Class"])
data = data.drop(["Time", "Class"], axis=1)

# %% [markdown]
# d. Normalisez toutes les colonnes de `data` vers des valeurs de moyenne nulle et d'écart-type égal à 1 (distribution centrée réduite). Utilisez pour cela le `StandardScaler` de scikit-learn.

# %%
scaled_data = StandardScaler().fit_transform(data)
data = pd.DataFrame(scaled_data, columns=data.columns)
data.head(10)
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.694242 -0.044075  1.672773  0.973366 -0.245117  0.347068  0.193679
# 1  0.608496  0.161176  0.109797  0.316523  0.043483 -0.061820 -0.063700
# 2 -0.693500 -0.811578  1.169468  0.268231 -0.364572  1.351454  0.639776
# 3 -0.493325 -0.112169  1.182516 -0.609727 -0.007469  0.936150  0.192071
# 4 -0.591330  0.531541  1.021412  0.284655 -0.295015  0.071999  0.479302
# 5 -0.217475  0.581675  0.752585 -0.118833  0.305009 -0.022313  0.384936
# 6  0.627795  0.085389  0.029923  0.849383  0.139020  0.204695 -0.004170
# 7 -0.328928  0.858692  0.708576 -0.347631  0.687512  0.321345  0.905860
# 8 -0.456573  0.173291 -0.074653 -0.191774  1.934149  2.793594  0.299206
# 9 -0.172698  0.678005  0.688781 -0.156927  0.361792 -0.185219  0.526706
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.082637  0.331128  0.083386  ...  0.326118 -0.024923  0.382854 -0.176911
# 1  0.071253 -0.232494 -0.153350  ... -0.089611 -0.307377 -0.880077  0.162201
# 2  0.207373 -1.378675  0.190700  ...  0.680975  0.337632  1.063358  1.456320
# 3  0.316018 -1.262503 -0.050468  ... -0.269855 -0.147443  0.007267 -0.304777
# 4 -0.226510  0.744326  0.691625  ...  0.529939 -0.012839  1.100011 -0.220123
# 5  0.217955 -0.517619 -0.341101  ...  0.110215 -0.283522 -0.771427 -0.042273
# 6  0.067998  0.423218 -0.091155  ... -0.284895 -0.228334 -0.373032 -0.246780
# 7 -3.188229  0.560129  1.147430  ... -0.203317  2.645889 -1.399276  0.092085
# 8  0.712592 -0.356851 -0.376940  ...  0.068406 -0.099963 -0.369425 -0.327055
# 9  0.058223 -0.670587 -0.336912  ...  0.264243 -0.336156 -0.873298 -0.193438
#
#         V24       V25       V26       V27       V28    Amount
# 0  0.110507  0.246585 -0.392170  0.330892 -0.063781  0.244964
# 1 -0.561131  0.320694  0.261069 -0.022256  0.044608 -0.342475
# 2 -1.138092 -0.628537 -0.288447 -0.137137 -0.181021  1.160686
# 3 -1.941027  1.241904 -0.460217  0.155396  0.186189  0.140534
# 4  0.233250 -0.395202  1.041611  0.543620  0.651816 -0.073403
# 5 -0.613273 -0.446584  0.219637  0.628900  0.245636 -0.338556
# 6 -1.287973  1.439037 -0.533436  0.085492  0.015656 -0.333279
# 7 -1.072754 -0.796633 -0.107075 -2.990154 -3.288083 -0.190107
# 8  1.670269  0.715943 -0.796633  0.029104  0.431420  0.019392
# 9 -0.635767 -0.133773  0.195342  0.610010  0.251681 -0.338516
#
# [10 rows x 29 columns]

# %% [markdown]
# e. Pourquoi est-il acceptable ici de ne pas diviser `data` en données d'entraînement et de test ?

# %% [markdown]
# **Réponse**: Parce que le but est de pouvoir reconstruire les données existantes à l'aide d'un auto-encodeur pour effectuer des comparaisons avec les données d'origine, il est donc plus utile d'utiliser le jeu de données entier plutôt que le diviser comme dans un problème de classification habituel.

# %% [markdown]
# # 2. Définir les fonctions d'évaluation du modèle
# Veuillez définir deux fonctions qui affichent :
#    1. la courbe précision-rappel et la précision moyenne (qui est aussi la valeur de retour)
#    1. la courbe ROC et l'aire sous la courbe (qui est aussi la valeur de retour)
#
# Puis, veuillez recopier leur code et écrire une fonction qui affiche les deux courbes ensemble.
#
# Ces fonctions, spécifiées ci-dessous, utilisent les classes et fonctions importées de `sklearn.metrics` au début de ce notebook.  Veuillez consulter leur documentation pour savoir comment les utiliser.
#
# Une fonction auxiliaire vous est donnée, qui mesure l'erreur de reconstruction entre les données d'origine et celles reconstruites par un autoencodeur.

# %%
def reconstruction_error(X_orig, X_pred):
    '''
    Mesure l'erreur de reconstruction pour l'ensemble des données (compare 2 dataframes).
    Retourne une série avec l'erreur de chaque point de données.
    '''
    loss = np.sum((np.array(X_orig) - np.array(X_pred))**2, axis=1) # carré de l'erreur pour chaque item
    loss = pd.Series(data = loss, index = X_orig.index) # transformer en Series
    loss = (loss - np.min(loss)) / (np.max(loss) - np.min(loss)) # normalisation sur tous les items vers [0, 1]
    return loss

# %% [markdown]
# Veuillez écrire une fonction pour afficher la courbe précision-rappel et retourner la précision moyenne.  Veuillez écrire une fonction pour afficher la courbe ROC.  Enfin, veuillez copier le code dans une fonction qui affiche les deux courbes ensemble.

# %%
def display_pr_curve(labels, rec_errors, baseline=[]):
    '''
    Affiche la courbe précision-rappel et retourne la moyenne de la précision.
    labels     = les classes correctes : {0, 1} pour chaque item
    rec_errors = les nombres prédits par l'autoencodeur pour chaque item, dans [0, 1]
    baseline   = les nombres prédits par une autre méthode, en général baseline, dans [0, 1]
    '''
    fig, ax = plt.subplots()

    precision, recall, _ = precision_recall_curve(labels, rec_errors)
    PrecisionRecallDisplay(precision=precision, recall=recall).plot(ax, name="rec_errors")
    
    if len(baseline) == len(labels):
        baseline_precision, baseline_recall, _ = precision_recall_curve(labels, baseline)
        PrecisionRecallDisplay(precision=baseline_precision, recall=baseline_recall).plot(ax, name="baseline")

    plt.legend(loc="best")
    plt.show()

# %%
def display_roc_curve(labels, rec_errors, baseline=[]):
    '''
    Affiche la courbe ROC et retourne l'aire sous la courbe ROC.
    labels     = les classes correctes : {0, 1} pour chaque item
    rec_errors = les nombres prédits par l'autoencodeur pour chaque item, dans [0, 1]
    baseline   = les nombres prédits par une autre méthode, en général baseline, dans [0, 1]
    '''
    fig, ax = plt.subplots()

    fpr, tpr, _ =  roc_curve(labels, rec_errors)
    RocCurveDisplay(fpr=fpr, tpr=tpr).plot(ax, name="rec_errors")

    if len(baseline) == len(labels):
        fpr, tpr, _ = roc_curve(labels, rec_errors)
        RocCurveDisplay(fpr=fpr, tpr=tpr).plot(ax, name="baseline")

    plt.legend(loc="best")
    plt.show()

# %%
def display_pr_roc(labels, rec_errors, baseline=[]):
    '''
    Affiche côte à côte la courbe précision-rappel et la courbe ROC. 
    Retourne la moyenne de la précision et l'aire sous la courbe ROC.
    labels     = les classes correctes : {0, 1} pour chaque item
    rec_errors = les nombres prédits par l'autoencodeur pour chaque item, dans [0, 1]
    baseline   = les nombres prédits par une autre méthode, en général baseline, dans [0, 1]
    '''

    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figwidth(12)

    precision, recall, _ = precision_recall_curve(labels, rec_errors)
    fpr, tpr, _ =  roc_curve(labels, rec_errors)

    PrecisionRecallDisplay(precision=precision, recall=recall).plot(ax1, name="rec_errors")
    RocCurveDisplay(fpr=fpr, tpr=tpr).plot(ax2, name="rec_errors")
    
    if len(baseline) == len(labels):
        baseline_precision, baseline_recall, _ = precision_recall_curve(labels, baseline)
        baseline_fpr, baseline_tpr, _ =  roc_curve(labels, baseline)

        PrecisionRecallDisplay(precision=baseline_precision, recall=baseline_recall).plot(ax1, name="baseline")
        RocCurveDisplay(fpr=baseline_fpr, tpr=baseline_tpr).plot(ax2, name="baseline")
    
    plt.legend(loc="best")
    plt.show()

    return average_precision_score(labels, rec_errors), roc_auc_score(labels, rec_errors)

# %% [markdown]
# ## 3. Tester des modèles *baseline*
#
# On considère deux modèles *baseline* pour des valeurs de reconstruction:
#    1. des scores aléatoires dans [0, 1] pour chaque item : `np.random.rand(data.shape[0])`
#    1. la norme L2 du vecteur d'attributs de chaque transaction, normalisée par colonne entre 0 et 1, qui peut être obtenue simplement ainsi avec la fonction définie plus haut : `reconstruction_error(data, np.zeros(data.shape[0]))`
#
# Veuillez afficher les courbes précision-rappel et ROC pour ces deux *baselines* en même temps, grâce à la fonction précédente.

# %%
baseline1 = np.random.rand(data.shape[0])
baseline2 = reconstruction_error(data, np.zeros(data.shape))

display_pr_roc(data_labels, baseline1)
display_pr_roc(data_labels, baseline2)
# Out:
# (0.14786658134012173, 0.9524827609477579)

# %% [markdown]
# Sachant que les données proviennent d'une transformation PCA des données de transaction originales (auxquelles nous n'avons pas accès), pouvez-vous tenter d'expliquer le score non-nul obtenu par la 2e baseline ?

# %% [markdown]
# **Réponse**: En utilisant la norme L2 des vecteurs on procède à une sorte de réduction de la dimensionalité finale vers une seule dimension. La prédiction est donc dérivée de l'information présente dans les données, d'où son score non-nul.

# %% [markdown]
# ## 4. Définir des fonctions pour entraîner, valider, et évaluer des modèles
#
# Veuillez définir une fonction `train` qui entraîne un *modèle* (que vous créerez plus bas avec Keras) sur un jeu de *données*, avec l'objectif de reconstruire les données (donc les données d'entrée et de sortie pour un entraînement supervisé sont identiques).  Toutes les *x* époques d'entraînement (`epochs_per_iteration`) la fonction `train` affiche les scores de *précision moyenne* et de *aire sous la courbe ROC*, mais pas les graphiques.  La fonction itère cela *y* fois (`nb_iterations`).
#
# Veuillez définir aussi une fonction `evaluate` qui affiche les courbes précision-rappel et ROC pour un modèle, et inclut dans chaque graphique la *baseline* de la norme L2 des données initiales (2e baseline de la section 3).
#
# Vous pouvez utiliser ces [méthodes de Keras](https://keras.io/api/models/model_training_apis) :
#    * [model.fit(...)](https://keras.io/api/models/model_training_apis/#fit-method) pour lancer un certain nombre de pas d'entraînement (*backward pass*)
#    * [model.predict(...)](https://keras.io/api/models/model_training_apis/#predict-method) pour exécuter le modèle sur des données et obtenir la sortie (*forward pass*)

# %%
def train(model, data, epochs_per_iteration = 10, nb_iterations = 10, display_scores=False):
    epoch = 0

    score_epochs = list()
    average_precision_scores = np.zeros(nb_iterations)
    roc_auc_scores = np.zeros(nb_iterations)

    for i in range(nb_iterations):
        print(f"Epochs {i*epochs_per_iteration+1}->{i*epochs_per_iteration+epochs_per_iteration}")
        model.fit(data, data, epochs=epochs_per_iteration)
        
        score_epochs.append(i*epochs_per_iteration+epochs_per_iteration)
        print("==>Checking scores...")
        rec_errors = reconstruction_error(data, model.predict(data))
        average_precision_scores[i] = average_precision_score(data_labels, rec_errors)
        roc_auc_scores[i] = roc_auc_score(data_labels, rec_errors)

        print(f"Average precision: {average_precision_scores[i]}")
        print(f"ROC AUC: {roc_auc_scores[i]}")

    if display_scores:
        plt.plot(score_epochs, average_precision_scores, label="Average precisions")
        plt.plot(score_epochs, roc_auc_scores, label="ROC AUC")

        plt.xlabel("Epoch")
        plt.ylabel("Score")
        plt.legend(loc="best")
        plt.show()

# %%
def evaluate(model, data, data_labels):
    baseline = reconstruction_error(data, np.zeros(data.shape))
    rec_errors = reconstruction_error(data, model.predict(data))

    scores = display_pr_roc(data_labels, rec_errors, baseline=baseline)
    base_scores = average_precision_score(data_labels, baseline), roc_auc_score(data_labels, baseline)

    print("(Average precision, ROC AUR):")
    print(f"model: {scores}")
    print(f"baseline: {base_scores}")

# %% [markdown]
# ## 5. Créer, entraîner et évaluer des autoencodeurs
#
# ### 5.1. Autoencodeur simple à trois couches
#
# Veuillez définir en Keras un autoencodeur à trois couches, avec une couche de codage ayant une dimension plus faible que celle d'entrée (*undercomplete autoencoder*).  Utiliser un modèle de type `Sequential()` avec des couches entièrement connectées de type `Dense()`, en vous guidant sur les [exemples de Keras](https://keras.io/api/models/sequential/).  Choisissez une fonction de coût (*loss*) et un optimiseur appropriés.  N'oubliez pas de [compiler le modèle](https://keras.io/api/models/model_training_apis/#compile-method) à la fin.

# %%
model1 = keras.Sequential(name="autoencodeur1")
model1.add(keras.layers.Dense(17, activation="relu", name="hidden"))
model1.add(keras.layers.Dense(data.shape[1], activation="relu", name="output"))

model1.compile(optimizer=keras.optimizers.Adadelta(learning_rate=0.05), loss="mse")

# %%
#model1.save('modele_1.h5')  # enregistrer le modèle
# del model  # supprimer le modèle de la mémoire
#model1 = keras.models.load_model('modele_1.h5') # charger le modèle

# %% [markdown]
# Veuillez entraîner le modèle avec la fonction `train` que vous avez définie plus haut.  Selon vos résultats intermédiaires, écrivez ici la commande qui semble suffisante pour atteindre le maximum de performance, et affichez ses résultats.  Notez que le modèle est sauvegardé, donc plusieurs appels à `train` permettent de continuer l'entraînement.  Dans votre rapport final, indiquez explicitement la durée totale en nombre d'époques.

# %%
train(model1, data, 10, 5, display_scores=True) # 50 epochs
# Out:
# Epochs 1->10
# Epoch 1/10
# 8901/8901 [==============================] - 5s 514us/step - loss: 0.9819
# Epoch 2/10
# 8901/8901 [==============================] - 5s 515us/step - loss: 0.8789
# Epoch 3/10
# 8901/8901 [==============================] - 5s 517us/step - loss: 0.8260
# Epoch 4/10
# 8901/8901 [==============================] - 5s 513us/step - loss: 0.7937
# Epoch 5/10
# 8901/8901 [==============================] - 5s 510us/step - loss: 0.7644
# Epoch 6/10
# 8901/8901 [==============================] - 5s 518us/step - loss: 0.7374
# Epoch 7/10
# 8901/8901 [==============================] - 5s 519us/step - loss: 0.7146
# Epoch 8/10
# 8901/8901 [==============================] - 5s 516us/step - loss: 0.6988
# Epoch 9/10
# 8901/8901 [==============================] - 5s 514us/step - loss: 0.6865
# Epoch 10/10
# 8901/8901 [==============================] - 5s 516us/step - loss: 0.6788
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 346us/step
# Average precision: 0.18105027917610295
# ROC AUC: 0.9490883165342916
# Epochs 11->20
# Epoch 1/10
# 8901/8901 [==============================] - 5s 520us/step - loss: 0.6736
# Epoch 2/10
# 8901/8901 [==============================] - 5s 519us/step - loss: 0.6698
# Epoch 3/10
# 8901/8901 [==============================] - 5s 518us/step - loss: 0.6668
# Epoch 4/10
# 8901/8901 [==============================] - 5s 529us/step - loss: 0.6642
# Epoch 5/10
# 8901/8901 [==============================] - 5s 518us/step - loss: 0.6619
# Epoch 6/10
# 8901/8901 [==============================] - 5s 520us/step - loss: 0.6599
# Epoch 7/10
# 8901/8901 [==============================] - 5s 517us/step - loss: 0.6579
# Epoch 8/10
# 8901/8901 [==============================] - 5s 513us/step - loss: 0.6562
# Epoch 9/10
# 8901/8901 [==============================] - 5s 513us/step - loss: 0.6547
# Epoch 10/10
# 8901/8901 [==============================] - 5s 509us/step - loss: 0.6532
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 356us/step
# Average precision: 0.1905713045312707
# ROC AUC: 0.9489266027932776
# Epochs 21->30
# Epoch 1/10
# 8901/8901 [==============================] - 5s 522us/step - loss: 0.6512
# Epoch 2/10
# 8901/8901 [==============================] - 5s 523us/step - loss: 0.6482
# Epoch 3/10
# 8901/8901 [==============================] - 5s 527us/step - loss: 0.6462
# Epoch 4/10
# 8901/8901 [==============================] - 5s 517us/step - loss: 0.6448
# Epoch 5/10
# 8901/8901 [==============================] - 5s 512us/step - loss: 0.6438
# Epoch 6/10
# 8901/8901 [==============================] - 5s 526us/step - loss: 0.6430
# Epoch 7/10
# 8901/8901 [==============================] - 5s 526us/step - loss: 0.6423
# Epoch 8/10
# 8901/8901 [==============================] - 5s 523us/step - loss: 0.6357
# Epoch 9/10
# 8901/8901 [==============================] - 5s 518us/step - loss: 0.6299
# Epoch 10/10
# 8901/8901 [==============================] - 5s 523us/step - loss: 0.6286
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 354us/step
# Average precision: 0.19168604775334097
# ROC AUC: 0.9514049314648572
# Epochs 31->40
# Epoch 1/10
# 8901/8901 [==============================] - 5s 524us/step - loss: 0.6279
# Epoch 2/10
# 8901/8901 [==============================] - 5s 522us/step - loss: 0.6273
# Epoch 3/10
# 8901/8901 [==============================] - 5s 521us/step - loss: 0.6268
# Epoch 4/10
# 8901/8901 [==============================] - 5s 529us/step - loss: 0.6263
# Epoch 5/10
# 8901/8901 [==============================] - 5s 534us/step - loss: 0.6258
# Epoch 6/10
# 8901/8901 [==============================] - 5s 516us/step - loss: 0.6255
# Epoch 7/10
# 8901/8901 [==============================] - 5s 516us/step - loss: 0.6251
# Epoch 8/10
# 8901/8901 [==============================] - 5s 516us/step - loss: 0.6247
# Epoch 9/10
# 8901/8901 [==============================] - 5s 514us/step - loss: 0.6243
# Epoch 10/10
# 8901/8901 [==============================] - 5s 523us/step - loss: 0.6239
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 361us/step
# Average precision: 0.19042039716442993
# ROC AUC: 0.9514945992714767
# Epochs 41->50
# Epoch 1/10
# 8901/8901 [==============================] - 5s 524us/step - loss: 0.6235
# Epoch 2/10
# 8901/8901 [==============================] - 5s 515us/step - loss: 0.6231
# Epoch 3/10
# 8901/8901 [==============================] - 5s 519us/step - loss: 0.6228
# Epoch 4/10
# 8901/8901 [==============================] - 5s 523us/step - loss: 0.6224
# Epoch 5/10
# 8901/8901 [==============================] - 5s 521us/step - loss: 0.6219
# Epoch 6/10
# 8901/8901 [==============================] - 5s 524us/step - loss: 0.6216
# Epoch 7/10
# 8901/8901 [==============================] - 5s 514us/step - loss: 0.6212
# Epoch 8/10
# 8901/8901 [==============================] - 5s 525us/step - loss: 0.6209
# Epoch 9/10
# 8901/8901 [==============================] - 5s 524us/step - loss: 0.6205
# Epoch 10/10
# 8901/8901 [==============================] - 5s 521us/step - loss: 0.6201
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 363us/step
# Average precision: 0.19002856383359332
# ROC AUC: 0.9514761838788393

# %% [markdown]
# Veuillez afficher les deux courbes (y compris les *baselines*), et les scores du modèle avec la fonction `evaluate`.

# %%
evaluate(model1, data, data_labels)
# Out:
# 8901/8901 [==============================] - 3s 365us/step
# (Average precision, ROC AUR):
# model: (0.19002856383359332, 0.9514761838788393)
# baseline: (0.14786658134012173, 0.9524827609477579)

# %% [markdown]
# **Veuillez discuter vos résultats.**  Comment jugez-vous la capacité du modèle à détecter des transactions frauduleuses, compte tenu du fait qu'il n'a jamais été entraîné de manière supervisée ?  Comment se compare-t-il avec la baseline ?  Quelle est sa précision maximale, et pour quel rappel est-elle atteinte ?  (Approximativement, d'après le graphique.)  Comment interprétez-vous ces valeurs ?

# %% [markdown]
# **Réponse**: Le modèle est loin d'être parfait, on aimerait bien que l'aire sous la courbe _Precision/Recall_ soit plus grande. La courbe _FPR/TPR_ présente cependant un profil plus satisfaisant et proche de l'idéal. Cela semble donc plutôt correct pour un modèle non-supervisé, qui s'est entraîné sans vraiment "viser" l'attribut cible lui-même. On arrive également à faire un peu mieux que la baseline avec ce premier modèle, en tout cas du point de vue _Precision/Recall_, les résultats _FPR/TPR_ étant plus similaires. Le maximum de précision hors valeur de _recall_ très faible vaut environ 0.5, pour un recall d'environ 0.2

# %% [markdown]
# ### 5.2. Autoencodeur à cinq couches
#
# Veuillez définir maintenant un autoencodeur à cinq couches, sur le même principe que le précédent, toujours *undercomplete*.  Effectuez son entraînement et son évaluation finale, comme pour le modèle à 3 couches.

# %%
model2 = keras.Sequential(name="autoencodeur2")
model2.add(keras.layers.Dense(19, activation="relu", name="hidden1"))
model2.add(keras.layers.Dense(17, activation="relu", name="hidden2"))
model2.add(keras.layers.Dense(15, activation="relu", name="hidden3"))
model2.add(keras.layers.Dense(data.shape[1], activation="relu", name="output"))

model2.compile(optimizer=keras.optimizers.Adadelta(learning_rate=0.05), loss="mse")

# %%
train(model2, data, 10, 10, display_scores=True) # 100 epochs
# Out:
# Epochs 1->10
# Epoch 1/10
# 8901/8901 [==============================] - 6s 602us/step - loss: 0.9800
# Epoch 2/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.9097
# Epoch 3/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.8554
# Epoch 4/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.8199
# Epoch 5/10
# 8901/8901 [==============================] - 5s 586us/step - loss: 0.7957
# Epoch 6/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.7773
# Epoch 7/10
# 8901/8901 [==============================] - 5s 592us/step - loss: 0.7644
# Epoch 8/10
# 8901/8901 [==============================] - 5s 587us/step - loss: 0.7519
# Epoch 9/10
# 8901/8901 [==============================] - 5s 591us/step - loss: 0.7395
# Epoch 10/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.7281
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 361us/step
# Average precision: 0.18572562517072216
# ROC AUC: 0.9531137740988932
# Epochs 11->20
# Epoch 1/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.7189
# Epoch 2/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.7130
# Epoch 3/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.7087
# Epoch 4/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.7052
# Epoch 5/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.7023
# Epoch 6/10
# 8901/8901 [==============================] - 5s 589us/step - loss: 0.6998
# Epoch 7/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6975
# Epoch 8/10
# 8901/8901 [==============================] - 5s 590us/step - loss: 0.6952
# Epoch 9/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6933
# Epoch 10/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6917
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 362us/step
# Average precision: 0.19125325915576719
# ROC AUC: 0.9528150744286403
# Epochs 21->30
# Epoch 1/10
# 8901/8901 [==============================] - 5s 591us/step - loss: 0.6903
# Epoch 2/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6888
# Epoch 3/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6875
# Epoch 4/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6863
# Epoch 5/10
# 8901/8901 [==============================] - 5s 591us/step - loss: 0.6851
# Epoch 6/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.6839
# Epoch 7/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6825
# Epoch 8/10
# 8901/8901 [==============================] - 5s 600us/step - loss: 0.6813
# Epoch 9/10
# 8901/8901 [==============================] - 5s 593us/step - loss: 0.6803
# Epoch 10/10
# 8901/8901 [==============================] - 5s 593us/step - loss: 0.6792
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 369us/step
# Average precision: 0.1948177397168544
# ROC AUC: 0.9530301184604446
# Epochs 31->40
# Epoch 1/10
# 8901/8901 [==============================] - 5s 606us/step - loss: 0.6781
# Epoch 2/10
# 8901/8901 [==============================] - 5s 609us/step - loss: 0.6770
# Epoch 3/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6761
# Epoch 4/10
# 8901/8901 [==============================] - 5s 596us/step - loss: 0.6752
# Epoch 5/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6744
# Epoch 6/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6738
# Epoch 7/10
# 8901/8901 [==============================] - 5s 605us/step - loss: 0.6733
# Epoch 8/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6728
# Epoch 9/10
# 8901/8901 [==============================] - 5s 600us/step - loss: 0.6724
# Epoch 10/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6715
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 372us/step
# Average precision: 0.19414293912937175
# ROC AUC: 0.9524826966082649
# Epochs 41->50
# Epoch 1/10
# 8901/8901 [==============================] - 5s 600us/step - loss: 0.6692
# Epoch 2/10
# 8901/8901 [==============================] - 5s 608us/step - loss: 0.6675
# Epoch 3/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6661
# Epoch 4/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6650
# Epoch 5/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6639
# Epoch 6/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6630
# Epoch 7/10
# 8901/8901 [==============================] - 5s 601us/step - loss: 0.6621
# Epoch 8/10
# 8901/8901 [==============================] - 5s 604us/step - loss: 0.6613
# Epoch 9/10
# 8901/8901 [==============================] - 5s 596us/step - loss: 0.6606
# Epoch 10/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6598
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 367us/step
# Average precision: 0.1944610523508316
# ROC AUC: 0.9516514303598622
# Epochs 51->60
# Epoch 1/10
# 8901/8901 [==============================] - 5s 593us/step - loss: 0.6591
# Epoch 2/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6584
# Epoch 3/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6577
# Epoch 4/10
# 8901/8901 [==============================] - 5s 602us/step - loss: 0.6571
# Epoch 5/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6564
# Epoch 6/10
# 8901/8901 [==============================] - 5s 604us/step - loss: 0.6559
# Epoch 7/10
# 8901/8901 [==============================] - 5s 592us/step - loss: 0.6554
# Epoch 8/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6550
# Epoch 9/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6546
# Epoch 10/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6542
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 381us/step
# Average precision: 0.19475396590328617
# ROC AUC: 0.9500939213619841
# Epochs 61->70
# Epoch 1/10
# 8901/8901 [==============================] - 5s 603us/step - loss: 0.6539
# Epoch 2/10
# 8901/8901 [==============================] - 5s 589us/step - loss: 0.6536
# Epoch 3/10
# 8901/8901 [==============================] - 5s 615us/step - loss: 0.6533
# Epoch 4/10
# 8901/8901 [==============================] - 5s 604us/step - loss: 0.6530
# Epoch 5/10
# 8901/8901 [==============================] - 5s 603us/step - loss: 0.6527
# Epoch 6/10
# 8901/8901 [==============================] - 5s 608us/step - loss: 0.6525
# Epoch 7/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6522
# Epoch 8/10
# 8901/8901 [==============================] - 5s 613us/step - loss: 0.6520
# Epoch 9/10
# 8901/8901 [==============================] - 5s 607us/step - loss: 0.6518
# Epoch 10/10
# 8901/8901 [==============================] - 5s 606us/step - loss: 0.6515
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 381us/step
# Average precision: 0.19498240268450467
# ROC AUC: 0.9499276681123037
# Epochs 71->80
# Epoch 1/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6513
# Epoch 2/10
# 8901/8901 [==============================] - 5s 606us/step - loss: 0.6511
# Epoch 3/10
# 8901/8901 [==============================] - 5s 601us/step - loss: 0.6509
# Epoch 4/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6507
# Epoch 5/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6505
# Epoch 6/10
# 8901/8901 [==============================] - 5s 585us/step - loss: 0.6502
# Epoch 7/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6500
# Epoch 8/10
# 8901/8901 [==============================] - 5s 594us/step - loss: 0.6498
# Epoch 9/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6496
# Epoch 10/10
# 8901/8901 [==============================] - 5s 604us/step - loss: 0.6494
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 365us/step
# Average precision: 0.1951087670070247
# ROC AUC: 0.9498982077733832
# Epochs 81->90
# Epoch 1/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6493
# Epoch 2/10
# 8901/8901 [==============================] - 5s 600us/step - loss: 0.6491
# Epoch 3/10
# 8901/8901 [==============================] - 5s 596us/step - loss: 0.6489
# Epoch 4/10
# 8901/8901 [==============================] - 5s 606us/step - loss: 0.6488
# Epoch 5/10
# 8901/8901 [==============================] - 5s 600us/step - loss: 0.6486
# Epoch 6/10
# 8901/8901 [==============================] - 5s 606us/step - loss: 0.6485
# Epoch 7/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6483
# Epoch 8/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6482
# Epoch 9/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6480
# Epoch 10/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6479
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 382us/step
# Average precision: 0.19521163461264113
# ROC AUC: 0.949900273785989
# Epochs 91->100
# Epoch 1/10
# 8901/8901 [==============================] - 5s 596us/step - loss: 0.6478
# Epoch 2/10
# 8901/8901 [==============================] - 5s 603us/step - loss: 0.6477
# Epoch 3/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6475
# Epoch 4/10
# 8901/8901 [==============================] - 5s 598us/step - loss: 0.6474
# Epoch 5/10
# 8901/8901 [==============================] - 5s 595us/step - loss: 0.6472
# Epoch 6/10
# 8901/8901 [==============================] - 5s 599us/step - loss: 0.6471
# Epoch 7/10
# 8901/8901 [==============================] - 5s 605us/step - loss: 0.6469
# Epoch 8/10
# 8901/8901 [==============================] - 5s 592us/step - loss: 0.6467
# Epoch 9/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6466
# Epoch 10/10
# 8901/8901 [==============================] - 5s 597us/step - loss: 0.6464
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 386us/step
# Average precision: 0.19539567536283334
# ROC AUC: 0.949916587421858

# %%
#model2.save('modele_2.h5')  # enregistrer le modèle
# del model  # supprimer le modèle de la mémoire
# model = keras.models.load_model('modele_1.h5') # charger le modèle

# %%
evaluate(model2, data, data_labels)
# Out:
# 8901/8901 [==============================] - 3s 381us/step
# (Average precision, ROC AUR):
# model: (0.19539567536283334, 0.949916587421858)
# baseline: (0.14786658134012173, 0.9524827609477579)

# %% [markdown]
# Veuillez discuter vos résultats et les comparer avec les précédents.

# %% [markdown]
# **Réponse**: On obtient une précision moyenne sensiblement meilleure que celle du modèle précédent, avec une précision maximum d'environ 0.55 pour un recall de 0.2. La courbe _FPR/TPR_ et son score d'aire restent très similaires.

# %% [markdown]
# ### 5.3. Autoencodeur à trois couches, *overcomplete*, avec *sparsity*
# Veuillez enfin définir un autoencodeur à trois couches, mais avec une couche cachée ayant une dimension supérieure à celle des couches d'entrée et de sortie.  Afin d'éviter la pure copie entrée/sortie, ajoutez une contrainte de régularisation sur la couche cachée, qui limite la somme des valeurs absolues des activations dans cette couche (voir la [documentation](https://keras.io/api/layers/regularizers/) de Keras).

# %%
model3 = keras.Sequential(name="autoencodeur3")
model3.add(keras.layers.Dense(72, activation="relu", name="hidden", activity_regularizer=keras.regularizers.L2(0.01)))
model3.add(keras.layers.Dense(data.shape[1], activation="relu", name="output"))
model3.compile(optimizer=keras.optimizers.Adadelta(learning_rate=0.05), loss="mse")

# %%
train(model3, data, 10, 8, display_scores=True) # 80 epochs
# Out:
# Epochs 1->10
# Epoch 1/10
# 8901/8901 [==============================] - 5s 574us/step - loss: 0.5189
# Epoch 2/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5188
# Epoch 3/10
# 8901/8901 [==============================] - 5s 553us/step - loss: 0.5187
# Epoch 4/10
# 8901/8901 [==============================] - 5s 572us/step - loss: 0.5187
# Epoch 5/10
# 8901/8901 [==============================] - 5s 562us/step - loss: 0.5186
# Epoch 6/10
# 8901/8901 [==============================] - 5s 554us/step - loss: 0.5185
# Epoch 7/10
# 8901/8901 [==============================] - 5s 544us/step - loss: 0.5185
# Epoch 8/10
# 8901/8901 [==============================] - 5s 553us/step - loss: 0.5184
# Epoch 9/10
# 8901/8901 [==============================] - 5s 574us/step - loss: 0.5183
# Epoch 10/10
# 8901/8901 [==============================] - 5s 573us/step - loss: 0.5183
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 362us/step
# Average precision: 0.22384281955523042
# ROC AUC: 0.949301866460094
# Epochs 11->20
# Epoch 1/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5182
# Epoch 2/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5182
# Epoch 3/10
# 8901/8901 [==============================] - 5s 573us/step - loss: 0.5181
# Epoch 4/10
# 8901/8901 [==============================] - 5s 568us/step - loss: 0.5181
# Epoch 5/10
# 8901/8901 [==============================] - 5s 567us/step - loss: 0.5180
# Epoch 6/10
# 8901/8901 [==============================] - 5s 575us/step - loss: 0.5180
# Epoch 7/10
# 8901/8901 [==============================] - 5s 568us/step - loss: 0.5179
# Epoch 8/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5179
# Epoch 9/10
# 8901/8901 [==============================] - 5s 571us/step - loss: 0.5178
# Epoch 10/10
# 8901/8901 [==============================] - 5s 573us/step - loss: 0.5178
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 372us/step
# Average precision: 0.22390312122966127
# ROC AUC: 0.9493069421312014
# Epochs 21->30
# Epoch 1/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5177
# Epoch 2/10
# 8901/8901 [==============================] - 5s 557us/step - loss: 0.5177
# Epoch 3/10
# 8901/8901 [==============================] - 5s 568us/step - loss: 0.5176
# Epoch 4/10
# 8901/8901 [==============================] - 5s 564us/step - loss: 0.5176
# Epoch 5/10
# 8901/8901 [==============================] - 5s 563us/step - loss: 0.5175
# Epoch 6/10
# 8901/8901 [==============================] - 5s 557us/step - loss: 0.5175
# Epoch 7/10
# 8901/8901 [==============================] - 5s 571us/step - loss: 0.5174
# Epoch 8/10
# 8901/8901 [==============================] - 5s 570us/step - loss: 0.5174
# Epoch 9/10
# 8901/8901 [==============================] - 5s 572us/step - loss: 0.5174
# Epoch 10/10
# 8901/8901 [==============================] - 5s 561us/step - loss: 0.5173
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 380us/step
# Average precision: 0.22399088340726467
# ROC AUC: 0.9493043328073223
# Epochs 31->40
# Epoch 1/10
# 8901/8901 [==============================] - 5s 562us/step - loss: 0.5173
# Epoch 2/10
# 8901/8901 [==============================] - 5s 556us/step - loss: 0.5172
# Epoch 3/10
# 8901/8901 [==============================] - 5s 567us/step - loss: 0.5172
# Epoch 4/10
# 8901/8901 [==============================] - 5s 575us/step - loss: 0.5172
# Epoch 5/10
# 8901/8901 [==============================] - 5s 576us/step - loss: 0.5171
# Epoch 6/10
# 8901/8901 [==============================] - 5s 563us/step - loss: 0.5171
# Epoch 7/10
# 8901/8901 [==============================] - 5s 559us/step - loss: 0.5171
# Epoch 8/10
# 8901/8901 [==============================] - 5s 572us/step - loss: 0.5170
# Epoch 9/10
# 8901/8901 [==============================] - 5s 542us/step - loss: 0.5170
# Epoch 10/10
# 8901/8901 [==============================] - 5s 562us/step - loss: 0.5170
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 390us/step
# Average precision: 0.22399661642755758
# ROC AUC: 0.9492917294155443
# Epochs 41->50
# Epoch 1/10
# 8901/8901 [==============================] - 5s 560us/step - loss: 0.5169
# Epoch 2/10
# 8901/8901 [==============================] - 5s 561us/step - loss: 0.5169
# Epoch 3/10
# 8901/8901 [==============================] - 5s 573us/step - loss: 0.5169
# Epoch 4/10
# 8901/8901 [==============================] - 5s 551us/step - loss: 0.5168
# Epoch 5/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5168
# Epoch 6/10
# 8901/8901 [==============================] - 5s 578us/step - loss: 0.5168
# Epoch 7/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5167
# Epoch 8/10
# 8901/8901 [==============================] - 5s 573us/step - loss: 0.5167
# Epoch 9/10
# 8901/8901 [==============================] - 5s 567us/step - loss: 0.5167
# Epoch 10/10
# 8901/8901 [==============================] - 5s 567us/step - loss: 0.5167
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 359us/step
# Average precision: 0.22399654573103117
# ROC AUC: 0.9492963761566988
# Epochs 51->60
# Epoch 1/10
# 8901/8901 [==============================] - 5s 575us/step - loss: 0.5166
# Epoch 2/10
# 8901/8901 [==============================] - 5s 574us/step - loss: 0.5166
# Epoch 3/10
# 8901/8901 [==============================] - 5s 575us/step - loss: 0.5166
# Epoch 4/10
# 8901/8901 [==============================] - 5s 559us/step - loss: 0.5166
# Epoch 5/10
# 8901/8901 [==============================] - 5s 551us/step - loss: 0.5165
# Epoch 6/10
# 8901/8901 [==============================] - 5s 561us/step - loss: 0.5165
# Epoch 7/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5165
# Epoch 8/10
# 8901/8901 [==============================] - 5s 553us/step - loss: 0.5165
# Epoch 9/10
# 8901/8901 [==============================] - 5s 552us/step - loss: 0.5164
# Epoch 10/10
# 8901/8901 [==============================] - 5s 571us/step - loss: 0.5164
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 367us/step
# Average precision: 0.22398390288557296
# ROC AUC: 0.9492848593874679
# Epochs 61->70
# Epoch 1/10
# 8901/8901 [==============================] - 5s 575us/step - loss: 0.5164
# Epoch 2/10
# 8901/8901 [==============================] - 5s 570us/step - loss: 0.5164
# Epoch 3/10
# 8901/8901 [==============================] - 5s 561us/step - loss: 0.5163
# Epoch 4/10
# 8901/8901 [==============================] - 5s 572us/step - loss: 0.5163
# Epoch 5/10
# 8901/8901 [==============================] - 5s 554us/step - loss: 0.5163
# Epoch 6/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5163
# Epoch 7/10
# 8901/8901 [==============================] - 5s 564us/step - loss: 0.5162
# Epoch 8/10
# 8901/8901 [==============================] - 5s 569us/step - loss: 0.5162
# Epoch 9/10
# 8901/8901 [==============================] - 5s 574us/step - loss: 0.5162
# Epoch 10/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5162
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 363us/step
# Average precision: 0.223953522332507
# ROC AUC: 0.9492849523222913
# Epochs 71->80
# Epoch 1/10
# 8901/8901 [==============================] - 5s 564us/step - loss: 0.5162
# Epoch 2/10
# 8901/8901 [==============================] - 5s 570us/step - loss: 0.5161
# Epoch 3/10
# 8901/8901 [==============================] - 5s 574us/step - loss: 0.5161
# Epoch 4/10
# 8901/8901 [==============================] - 5s 571us/step - loss: 0.5161
# Epoch 5/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5161
# Epoch 6/10
# 8901/8901 [==============================] - 5s 566us/step - loss: 0.5161
# Epoch 7/10
# 8901/8901 [==============================] - 5s 572us/step - loss: 0.5160
# Epoch 8/10
# 8901/8901 [==============================] - 5s 562us/step - loss: 0.5160
# Epoch 9/10
# 8901/8901 [==============================] - 5s 561us/step - loss: 0.5160
# Epoch 10/10
# 8901/8901 [==============================] - 5s 570us/step - loss: 0.5160
# ==>Checking scores...
# 8901/8901 [==============================] - 3s 369us/step
# Average precision: 0.223968697112457
# ROC AUC: 0.9492848808339656

# %%
# model.save('modele_3.h5')  # enregistrer le modèle
# del model  # supprimer le modèle de la mémoire
# model = keras.models.load_model('modele_1.h5') # charger le modèle

# %%
evaluate(model3, data, data_labels)
# Out:
# 8901/8901 [==============================] - 3s 358us/step
# (Average precision, ROC AUR):
# model: (0.223968697112457, 0.9492848808339656)
# baseline: (0.14786658134012173, 0.9524827609477579)

# %% [markdown]
# Veuillez discuter vos résultats et les comparer avec les précédents.

# %% [markdown]
# **Réponse**: La précision moyenne est encore une fois un peu améliorée par rapport aux modèles précédents, avec un maximum de précision valant environ 0.6 pour un recall d'environ 0.2. On peut dire qu'il s'agit du meilleur modèle obtenu jusqu'à maintenant.

# %% [markdown]
# ### Fin du laboratoire 6
# Veuillez nettoyer le *notebook* et y inclure l'affichage des résultats de vos systèmes définitifs.  Ne pas effacer les logs d'entraînement et les graphiques.  Veuillez ensuite soumettre le *notebook* sur Cyberlearn.
